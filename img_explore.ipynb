# %%
import torch

device = torch.device("cuda")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from utils import crop_turtle, display_cropped_images

turtle_id = "t001"
metadata_path = "metadata_splits_head.csv"
dataset_path = "data/turtle-data"

cropped_results = crop_turtle(
    turtle_id,
    metadata_path,
    dataset_path
)

display_cropped_images(cropped_results, max_display=20)
# Out:
# Loading metadata from data/turtle-data/metadata_splits_head.csv
# Successfully cropped 22 images for t001
